# %% [markdown]
# ![00-holding-munich-travel-guide.jpg.webp](data:image/webp;base64,...)

# %% [markdown]
# # **Monatszahlen Verkehrsunfälle**
#
# Der Datensatz Monatszahlen Verkehrsunfälle beinhaltetdie Themen
#
#
#
# *   Verkehrsunfälle
# *   Fluchtunfälle
#
#
# *   Alkoholunfälle

# %% [markdown]
# # DAS ZIEL DIESES PROJEKT:
# Visualisieren Sie historisch die Anzahl der Unfälle pro Kategorie (Spalte 1). Der Datensatz enthält derzeit Werte bis Ende 2020. Erstellen Sie eine Anwendung, die die Werte prognostiziert für:
#
#
#
# *   category: 'Alkoholunfälle'
# *   Type: 'insgesamt
#
# *   Jahr: '2021'
# *   Monat: '01'

# %% [markdown]
# # **1-Import liberaries**

# %%
pip install dabl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: dabl in /usr/local/lib/python3.10/dist-packages (0.2.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from dabl) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from dabl) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.1 in /usr/local/lib/python3.10/dist-packages (from dabl) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from dabl) (1.5.3)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.10/dist-packages (from dabl) (3.7.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from dabl) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->dabl) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->dabl) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->dabl) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->dabl) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->dabl) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->dabl) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->dabl) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->dabl) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.1->dabl) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.1->dabl) (3.1.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->dabl) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5->dabl) (1.16.0)

# %%
import numpy as np
import pandas as pd
from prophet import Prophet
import dabl
import seaborn as sns
import matplotlib.pyplot as plt
#from statsmodels.tools.eval_measures import rmse
import pickle
from datetime import datetime
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # **2-Upload dataset**

# %%
df=pd.read_csv('https://opendata.muenchen.de/dataset/5e73a82b-7cfb-40cc-9b30-45fe5a3fa24e/resource/40094bd6-f82d-4979-949b-26c8dc00b9a7/download/monatszahlen2209_verkehrsunfaelle.csv')
df.head()
# Out:
#        MONATSZAHL AUSPRÄGUNG  JAHR   MONAT  WERT  VORJAHRESWERT  \
# 0  Alkoholunfälle  insgesamt  2022  202201   NaN           16.0
# 1  Alkoholunfälle  insgesamt  2022  202202   NaN           14.0
# 2  Alkoholunfälle  insgesamt  2022  202203   NaN           24.0
# 3  Alkoholunfälle  insgesamt  2022  202204   NaN           16.0
# 4  Alkoholunfälle  insgesamt  2022  202205   NaN           24.0
#
#    VERÄND_VORMONAT_PROZENT  VERÄND_VORJAHRESMONAT_PROZENT  \
# 0                      NaN                            NaN
# 1                      NaN                            NaN
# 2                      NaN                            NaN
# 3                      NaN                            NaN
# 4                      NaN                            NaN
#
#    ZWÖLF_MONATE_MITTELWERT
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
df.tail()
# Out:
#            MONATSZAHL              AUSPRÄGUNG  JAHR   MONAT   WERT  \
# 2081  Verkehrsunfälle  Verletzte und Getötete  2000  200008  647.0
# 2082  Verkehrsunfälle  Verletzte und Getötete  2000  200009  675.0
# 2083  Verkehrsunfälle  Verletzte und Getötete  2000  200010  615.0
# 2084  Verkehrsunfälle  Verletzte und Getötete  2000  200011  578.0
# 2085  Verkehrsunfälle  Verletzte und Getötete  2000  200012  515.0
#
#       VORJAHRESWERT  VERÄND_VORMONAT_PROZENT  VERÄND_VORJAHRESMONAT_PROZENT  \
# 2081            NaN                   -13.04                            NaN
# 2082            NaN                     4.33                            NaN
# 2083            NaN                    -8.89                            NaN
# 2084            NaN                    -6.02                            NaN
# 2085            NaN                   -10.90                            NaN
#
#       ZWÖLF_MONATE_MITTELWERT
# 2081                    584.0
# 2082                    594.0
# 2083                    596.0
# 2084                    594.0
# 2085                    588.0

# %%
df.shape
# Out:
# (2086, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2086 entries, 0 to 2085
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   MONATSZAHL                     2086 non-null   object
#  1   AUSPRÄGUNG                     2086 non-null   object
#  2   JAHR                           2086 non-null   int64
#  3   MONAT                          2086 non-null   object
#  4   WERT                           2002 non-null   float64
#  5   VORJAHRESWERT                  1995 non-null   float64
#  6   VERÄND_VORMONAT_PROZENT        1840 non-null   float64
#  7   VERÄND_VORJAHRESMONAT_PROZENT  1910 non-null   float64
#  8   ZWÖLF_MONATE_MITTELWERT        1848 non-null   float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 146.8+ KB

# %% [markdown]
# # **3-Data pre-processing**

# %%
# Process the data - considering first 5 columns
#Select only important columns
features = ['MONATSZAHL', 'AUSPRÄGUNG', 'JAHR', 'MONAT', 'WERT']
#Make the data only the important columns
df = df[features]

# %%
df.head()
# Out:
#        MONATSZAHL AUSPRÄGUNG  JAHR   MONAT  WERT
# 0  Alkoholunfälle  insgesamt  2022  202201   NaN
# 1  Alkoholunfälle  insgesamt  2022  202202   NaN
# 2  Alkoholunfälle  insgesamt  2022  202203   NaN
# 3  Alkoholunfälle  insgesamt  2022  202204   NaN
# 4  Alkoholunfälle  insgesamt  2022  202205   NaN

# %%
data = df.copy() #saved raw copy to use it later

# %%
df['MONATSZAHL'].unique()
# Out:
# array(['Alkoholunfälle', 'Fluchtunfälle', 'Verkehrsunfälle'], dtype=object)

# %%
df['AUSPRÄGUNG'].unique()
# Out:
# array(['insgesamt', 'Verletzte und Getötete', 'mit Personenschäden'],
#       dtype=object)

# %%
df['JAHR'].unique()
# Out:
# array([2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012,
#        2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001,
#        2000])

# %%
df['MONAT'].unique()
# Out:
# array(['202201', '202202', '202203', '202204', '202205', '202206',
#        '202207', '202208', '202209', '202210', '202211', '202212',
#        'Summe', '202101', '202102', '202103', '202104', '202105',
#        '202106', '202107', '202108', '202109', '202110', '202111',
#        '202112', '202001', '202002', '202003', '202004', '202005',
#        '202006', '202007', '202008', '202009', '202010', '202011',
#        '202012', '201901', '201902', '201903', '201904', '201905',
#        '201906', '201907', '201908', '201909', '201910', '201911',
#        '201912', '201801', '201802', '201803', '201804', '201805',
#        '201806', '201807', '201808', '201809', '201810', '201811',
#        '201812', '201701', '201702', '201703', '201704', '201705',
#        '201706', '201707', '201708', '201709', '201710', '201711',
#        '201712', '201601', '201602', '201603', '201604', '201605',
#        '201606', '201607', '201608', '201609', '201610', '201611',
#        '201612', '201501', '201502', '201503', '201504', '201505',
#        '201506', '201507', '201508', '201509', '201510', '201511',
#        '201512', '201401', '201402', '201403', '201404', '201405',
#        '201406', '201407', '201408', '201409', '201410', '201411',
#        '201412', '201301', '201302', '201303', '201304', '201305',
#        '201306', '201307', '201308', '201309', '201310', '201311',
#        '201312', '201201', '201202', '201203', '201204', '201205',
#        '201206', '201207', '201208', '201209', '201210', '201211',
#        '201212', '201101', '201102', '201103', '201104', '201105',
#        '201106', '201107', '201108', '201109', '201110', '201111',
#        '201112', '201001', '201002', '201003', '201004', '201005',
#        '201006', '201007', '201008', '201009', '201010', '201011',
#        '201012', '200901', '200902', '200903', '200904', '200905',
#        '200906', '200907', '200908', '200909', '200910', '200911',
#        '200912', '200801', '200802', '200803', '200804', '200805',
#        '200806', '200807', '200808', '200809', '200810', '200811',
#        '200812', '200701', '200702', '200703', '200704', '200705',
#        '200706', '200707', '200708', '200709', '200710', '200711',
#        '200712', '200601', '200602', '200603', '200604', '200605',
#        '200606', '200607', '200608', '200609', '200610', '200611',
#        '200612', '200501', '200502', '200503', '200504', '200505',
#        '200506', '200507', '200508', '200509', '200510', '200511',
#        '200512', '200401', '200402', '200403', '200404', '200405',
#        '200406', '200407', '200408', '200409', '200410', '200411',
#        '200412', '200301', '200302', '200303', '200304', '200305',
#        '200306', '200307', '200308', '200309', '200310', '200311',
#        '200312', '200201', '200202', '200203', '200204', '200205',
#        '200206', '200207', '200208', '200209', '200210', '200211',
#        '200212', '200101', '200102', '200103', '200104', '200105',
#        '200106', '200107', '200108', '200109', '200110', '200111',
#        '200112', '200001', '200002', '200003', '200004', '200005',
#        '200006', '200007', '200008', '200009', '200010', '200011',
#        '200012'], dtype=object)

# %% [markdown]
# **check for non-numeric values,replace Non-numeric value and empty values with NaN and drop rows with missing values in the numeric columns**

# %%
numeric_cols = ['JAHR', 'MONAT', 'WERT']
for col in numeric_cols:
    # replace Non-numeric value and empty values with NaN
    df.loc[:, col] = pd.to_numeric(df[col],downcast="integer", errors='coerce').astype('Int64')   #modifying the original DataFrame and not a copy of it.

df = df.dropna(subset=numeric_cols).reset_index(drop=True)

# check for missing values after dropping
print(df[numeric_cols].isnull().any())
# Out:
# JAHR     False
# MONAT    False
# WERT     False
# dtype: bool
# <ipython-input-66-5ade602f36ca>:4: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, col] = pd.to_numeric(df[col],downcast="integer", errors='coerce').astype('Int64')   #modifying the original DataFrame and not a copy of it.

# %% [markdown]
# **change 'MONAT' TO date time format**

# %%
df['MONAT'] = pd.to_datetime(df['MONAT'], format='%Y%m').dt.month
df.head()
# Out:
#        MONATSZAHL AUSPRÄGUNG  JAHR  MONAT  WERT
# 0  Alkoholunfälle  insgesamt  2021      1    16
# 1  Alkoholunfälle  insgesamt  2021      2    14
# 2  Alkoholunfälle  insgesamt  2021      3    24
# 3  Alkoholunfälle  insgesamt  2021      4    16
# 4  Alkoholunfälle  insgesamt  2021      5    24

# %% [markdown]
# **Remove the values in the 'JAHR' column is equal to "Summe".**

# %%
df.drop(df[df["JAHR"]=="Summe"].index,inplace=True)
df.head()
# Out:
#        MONATSZAHL AUSPRÄGUNG  JAHR  MONAT  WERT
# 0  Alkoholunfälle  insgesamt  2021      1    16
# 1  Alkoholunfälle  insgesamt  2021      2    14
# 2  Alkoholunfälle  insgesamt  2021      3    24
# 3  Alkoholunfälle  insgesamt  2021      4    16
# 4  Alkoholunfälle  insgesamt  2021      5    24

# %% [markdown]
# **calculates the sum of missing values in each column.**

# %%
df.isnull().sum()
# Out:
# MONATSZAHL    0
# AUSPRÄGUNG    0
# JAHR          0
# MONAT         0
# WERT          0
# dtype: int64

# %% [markdown]
# # **4-Data Exploration**

# %% [markdown]
# **Number of accidents every year**

# %%
(df.groupby([df.JAHR,df.MONATSZAHL]).MONATSZAHL.count()).unstack()
# Out:
# MONATSZAHL  Alkoholunfälle  Fluchtunfälle  Verkehrsunfälle
# JAHR
# 2000                    24             24               36
# 2001                    24             24               36
# 2002                    24             24               36
# 2003                    24             24               36
# 2004                    24             24               36
# 2005                    24             24               36
# 2006                    24             24               36
# 2007                    24             24               36
# 2008                    24             24               36
# 2009                    24             24               36
# 2010                    24             24               36
# 2011                    24             24               36
# 2012                    24             24               36
# 2013                    24             24               36
# 2014                    24             24               36
# 2015                    24             24               36
# 2016                    24             24               36
# 2017                    24             24               36
# 2018                    24             24               36
# 2019                    24             24               36
# 2020                    24             24               36
# 2021                    24             24               36

# %% [markdown]
# **represents the count of occurrences for each value in the 'MONATSZAHL', NOTE'Verkehrsunfälle'is high in all years**

# %%
print(df['MONATSZAHL'].value_counts())
df['MONATSZAHL'].value_counts().plot(kind='bar',color='green')
# Out:
# Verkehrsunfälle    792
# Alkoholunfälle     528
# Fluchtunfälle      528
# Name: MONATSZAHL, dtype: int64
# <Axes: >

# %% [markdown]
# **Number of accident per 'MONAT by MONATSZAHL**

# %%
(df.groupby([df.MONAT,df.MONATSZAHL]).MONATSZAHL.count()).unstack()
# Out:
# MONATSZAHL  Alkoholunfälle  Fluchtunfälle  Verkehrsunfälle
# MONAT
# 1                       44             44               66
# 2                       44             44               66
# 3                       44             44               66
# 4                       44             44               66
# 5                       44             44               66
# 6                       44             44               66
# 7                       44             44               66
# 8                       44             44               66
# 9                       44             44               66
# 10                      44             44               66
# 11                      44             44               66
# 12                      44             44               66

# %% [markdown]
# **Here is the graph shows all the months are sharing equal number of accident**

# %%
print(df['MONAT'].value_counts())
df['MONAT'].value_counts().plot(kind='bar',color='green')
# Out:
# 1     154
# 2     154
# 3     154
# 4     154
# 5     154
# 6     154
# 7     154
# 8     154
# 9     154
# 10    154
# 11    154
# 12    154
# Name: MONAT, dtype: int64
# <Axes: >

# %%
dabl.plot(df, target_col='WERT')
# Out:
# Target looks like regression
# [<Axes: title={'center': 'Target distribution'}, xlabel='WERT', ylabel='frequency'>,
#  array([[<Axes: title={'center': 'F=7.23E-02'}, xlabel='MONAT (jittered)', ylabel='WERT'>,
#          <Axes: title={'center': 'F=-5.50E-02'}, xlabel='JAHR (jittered)'>]],
#        dtype=object),
#  array([[<Axes: title={'center': 'F=7.65E-01'}, xlabel='WERT', ylabel='MONATSZAHL'>,
#          <Axes: title={'center': 'F=4.85E-01'}, xlabel='WERT', ylabel='AUSPRÄGUNG'>]],
#        dtype=object)]

# %% [markdown]
# **from the bellow visualization wshows that the Verkehrsunfälle Accident category the maximun times happend**

# %%
plt.figure(figsize=(6, 5))

# Define the desired color palette
colors = ["#FF7F00", "#1F77B4", "#FFD700"]

# Plot the countplot with the specified color palette
sns.countplot(x='MONAT', hue='MONATSZAHL', data=df, palette=colors)

plt.xlabel('MONAT')
plt.xticks(rotation=60)
plt.show()

# %%
plt.figure(figsize=(6, 5))

# Define the desired color palette
colors = ["#FF7F00", "#1F77B4", "#FFD700"]

# Plot the countplot with the specified color palette
sns.countplot(x='JAHR', hue='MONATSZAHL', data=df, palette=colors)

plt.xlabel('JAHR')
plt.xticks(rotation=60)
plt.show()

# %%
sns.distplot(df.WERT,color='green')
plt.show()
# Out:
# <ipython-input-77-17236b5c9c90>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.WERT,color='green')

# %% [markdown]
# **From the belw graph the target column data is not normally disributed.**

# %%
color='green'
df.WERT.hist(color=color)
# Out:
# <Axes: >

# %% [markdown]
# **To visualize the co-orelation coefficient**

# %%
corr = df.corr(method = 'spearman')
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
# Out:
# <ipython-input-79-e89756e86256>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr(method = 'spearman')
# <Axes: >

# %%
df_2020 = data[data['JAHR'] < 2021]

Verkehrsunfälle = df_2020[( (df_2020['MONATSZAHL'] == 'Verkehrsunfälle') & (df_2020['MONAT'] == 'Summe') & (df_2020['AUSPRÄGUNG'] == 'insgesamt') )]
Fluchtunfälle = df_2020[((df_2020['MONATSZAHL'] == 'Fluchtunfälle') & (df_2020['MONAT'] == 'Summe') &(df_2020['AUSPRÄGUNG'] == 'insgesamt') )]
Alkoholunfälle = df_2020[( (df_2020['MONATSZAHL'] == 'Alkoholunfälle') &(df_2020['MONAT'] == 'Summe') &(df_2020['AUSPRÄGUNG'] == 'insgesamt') )]

years = [i for i in range(2000, 2021)]
years.sort(reverse=True)

accidents_WERT = pd.DataFrame({
        "Verkehrsunfälle": Verkehrsunfälle['WERT'].to_numpy(),
        "Fluchtunfälle": Fluchtunfälle['WERT'].to_numpy(),
        "Alkoholunfälle": Alkoholunfälle['WERT'].to_numpy()  },
    index= years )

accidents_WERT.plot(kind='area', colormap='Set2')
plt.gcf().set_size_inches(9, 6)

accidents_WERT.plot(kind='bar', stacked=True, colormap='Set3')
plt.gcf().set_size_inches(9, 6)

accidents_WERT.plot(kind='bar', colormap='Dark2')
plt.gcf().set_size_inches(9, 6)

accidents_WERT.plot(colormap='Paired')
plt.gcf().set_size_inches(9, 6)

# %%
# Plot Number of accidents per category
plot = sns.catplot(x="MONATSZAHL", kind="count", data=df, palette="Set2")
plt.title('Number of accidents per category')
plt.gcf().set_size_inches(9,6)

# Plot Number of accidents per Accident Type
plot = sns.catplot(x="AUSPRÄGUNG", kind="count", data=df, palette="Set3")
plt.title('Number of accidents per Accident Type')
plt.gcf().set_size_inches(9,6)

# %% [markdown]
# # **5-TIME SERIES**

# %% [markdown]
# **Change the names of the columnes and drop the columnes after 2020**

# %%
df = df.rename( columns = {
    'JAHR'       : 'Year',
    'MONAT'      : 'Month',
    'WERT'       : 'y',
    'MONATSZAHL': 'Category',
    'AUSPRÄGUNG': 'Accident-type'
})
df = df[df['Year'] <= 2020]
df
# Out:
#              Category           Accident-type  Year  Month    y
# 12     Alkoholunfälle               insgesamt  2020      1   28
# 13     Alkoholunfälle               insgesamt  2020      2   40
# 14     Alkoholunfälle               insgesamt  2020      3   27
# 15     Alkoholunfälle               insgesamt  2020      4   26
# 16     Alkoholunfälle               insgesamt  2020      5   40
# ...               ...                     ...   ...    ...  ...
# 1843  Verkehrsunfälle  Verletzte und Getötete  2000      8  647
# 1844  Verkehrsunfälle  Verletzte und Getötete  2000      9  675
# 1845  Verkehrsunfälle  Verletzte und Getötete  2000     10  615
# 1846  Verkehrsunfälle  Verletzte und Getötete  2000     11  578
# 1847  Verkehrsunfälle  Verletzte und Getötete  2000     12  515
#
# [1764 rows x 5 columns]

# %%
print(df['Year'])
# Out:
# 12      2020
# 13      2020
# 14      2020
# 15      2020
# 16      2020
#         ...
# 1843    2000
# 1844    2000
# 1845    2000
# 1846    2000
# 1847    2000
# Name: Year, Length: 1764, dtype: Int64

# %% [markdown]
# **create a day column**

# %%
df['Day'] = 1

# %% [markdown]
# **create a new column 'ds' in the DataFrame 'df' by combining the 'Day', 'Month', and 'Year' columns**

# %%
df['ds'] = pd.to_datetime(df[['Day', 'Month', 'Year']])
df.head()
# Out:
#           Category Accident-type  Year  Month   y  Day         ds
# 12  Alkoholunfälle     insgesamt  2020      1  28    1 2020-01-01
# 13  Alkoholunfälle     insgesamt  2020      2  40    1 2020-02-01
# 14  Alkoholunfälle     insgesamt  2020      3  27    1 2020-03-01
# 15  Alkoholunfälle     insgesamt  2020      4  26    1 2020-04-01
# 16  Alkoholunfälle     insgesamt  2020      5  40    1 2020-05-01

# %% [markdown]
# **set accident type to 'insgesamt' only**

# %%
df = df.loc[(df['Accident-type'] == 'insgesamt')]
df
# Out:
#              Category Accident-type  Year  Month     y  Day         ds
# 12     Alkoholunfälle     insgesamt  2020      1    28    1 2020-01-01
# 13     Alkoholunfälle     insgesamt  2020      2    40    1 2020-02-01
# 14     Alkoholunfälle     insgesamt  2020      3    27    1 2020-03-01
# 15     Alkoholunfälle     insgesamt  2020      4    26    1 2020-04-01
# 16     Alkoholunfälle     insgesamt  2020      5    40    1 2020-05-01
# ...               ...           ...   ...    ...   ...  ...        ...
# 1315  Verkehrsunfälle     insgesamt  2000      8  3387    1 2000-08-01
# 1316  Verkehrsunfälle     insgesamt  2000      9  3807    1 2000-09-01
# 1317  Verkehrsunfälle     insgesamt  2000     10  4117    1 2000-10-01
# 1318  Verkehrsunfälle     insgesamt  2000     11  3931    1 2000-11-01
# 1319  Verkehrsunfälle     insgesamt  2000     12  3789    1 2000-12-01
#
# [756 rows x 7 columns]

# %% [markdown]
# **separate the categories into various dataframes dependeing on their types to use Alkoholunfälle later**

# %%
df_alk = df.loc[(df['Category'] == 'Alkoholunfälle')]
df_flucht = df.loc[(df['Category'] == 'Fluchtunfälle')]
df_verkehr = df.loc[(df['Category'] == 'Verkehrsunfälle')]

# %%
df_alk
# Out:
#            Category Accident-type  Year  Month   y  Day         ds
# 12   Alkoholunfälle     insgesamt  2020      1  28    1 2020-01-01
# 13   Alkoholunfälle     insgesamt  2020      2  40    1 2020-02-01
# 14   Alkoholunfälle     insgesamt  2020      3  27    1 2020-03-01
# 15   Alkoholunfälle     insgesamt  2020      4  26    1 2020-04-01
# 16   Alkoholunfälle     insgesamt  2020      5  40    1 2020-05-01
# ..              ...           ...   ...    ...  ..  ...        ...
# 259  Alkoholunfälle     insgesamt  2000      8  77    1 2000-08-01
# 260  Alkoholunfälle     insgesamt  2000      9  84    1 2000-09-01
# 261  Alkoholunfälle     insgesamt  2000     10  83    1 2000-10-01
# 262  Alkoholunfälle     insgesamt  2000     11  71    1 2000-11-01
# 263  Alkoholunfälle     insgesamt  2000     12  85    1 2000-12-01
#
# [252 rows x 7 columns]

# %%
df_flucht
# Out:
#           Category Accident-type  Year  Month     y  Day         ds
# 540  Fluchtunfälle     insgesamt  2020      1   791    1 2020-01-01
# 541  Fluchtunfälle     insgesamt  2020      2   870    1 2020-02-01
# 542  Fluchtunfälle     insgesamt  2020      3   744    1 2020-03-01
# 543  Fluchtunfälle     insgesamt  2020      4   607    1 2020-04-01
# 544  Fluchtunfälle     insgesamt  2020      5   859    1 2020-05-01
# ..             ...           ...   ...    ...   ...  ...        ...
# 787  Fluchtunfälle     insgesamt  2000      8   881    1 2000-08-01
# 788  Fluchtunfälle     insgesamt  2000      9   978    1 2000-09-01
# 789  Fluchtunfälle     insgesamt  2000     10  1078    1 2000-10-01
# 790  Fluchtunfälle     insgesamt  2000     11  1017    1 2000-11-01
# 791  Fluchtunfälle     insgesamt  2000     12   950    1 2000-12-01
#
# [252 rows x 7 columns]

# %%
df_verkehr
# Out:
#              Category Accident-type  Year  Month     y  Day         ds
# 1068  Verkehrsunfälle     insgesamt  2020      1  3139    1 2020-01-01
# 1069  Verkehrsunfälle     insgesamt  2020      2  3271    1 2020-02-01
# 1070  Verkehrsunfälle     insgesamt  2020      3  2825    1 2020-03-01
# 1071  Verkehrsunfälle     insgesamt  2020      4  2251    1 2020-04-01
# 1072  Verkehrsunfälle     insgesamt  2020      5  3193    1 2020-05-01
# ...               ...           ...   ...    ...   ...  ...        ...
# 1315  Verkehrsunfälle     insgesamt  2000      8  3387    1 2000-08-01
# 1316  Verkehrsunfälle     insgesamt  2000      9  3807    1 2000-09-01
# 1317  Verkehrsunfälle     insgesamt  2000     10  4117    1 2000-10-01
# 1318  Verkehrsunfälle     insgesamt  2000     11  3931    1 2000-11-01
# 1319  Verkehrsunfälle     insgesamt  2000     12  3789    1 2000-12-01
#
# [252 rows x 7 columns]

# %%
len(df)
# Out:
# 756

# %%
train = df.iloc[:len(df)-365]
test = df.iloc[len(df)-365:]

# %% [markdown]
# **Make predictions **

# %% [markdown]
# **Apply time series on alchol dataframe and Fitting monthly data and making monthly forecasts for the next 12 months**

# %%
m = Prophet()
m.fit(df_alk)

# Specify the end date for the prediction (January 2021)
end_date = datetime(year=2021, month=1, day=31)

# Calculate the number of periods from the last available date to the end date
last_date = df_alk['ds'].max()
num_periods = (end_date - last_date).days

# Create a future dataframe with the specified number of periods
future = m.make_future_dataframe(periods=num_periods)

# Generate the forecast up to the end date
forecast = m.predict(future)

# Filter the forecast to include only the period up to the end date
forecast = forecast[forecast['ds'] <= end_date]
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp99zto3q6/u1xhzmbk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp99zto3q6/6gw98zlr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17713', 'data', 'file=/tmp/tmp99zto3q6/u1xhzmbk.json', 'init=/tmp/tmp99zto3q6/6gw98zlr.json', 'output', 'file=/tmp/tmp99zto3q6/prophet_modelegke1dt8/prophet_model-20230625152920.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:29:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:29:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
future
# Out:
#             ds
# 0   2000-01-01
# 1   2000-02-01
# 2   2000-03-01
# 3   2000-04-01
# 4   2000-05-01
# ..         ...
# 308 2021-01-27
# 309 2021-01-28
# 310 2021-01-29
# 311 2021-01-30
# 312 2021-01-31
#
# [313 rows x 1 columns]

# %%
forecast
# Out:
#             ds      trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0   2000-01-01  76.097544   55.472914   74.363360    76.097544    76.097544
# 1   2000-02-01  75.739631   52.643615   71.979462    75.739631    75.739631
# 2   2000-03-01  75.404810   57.323196   77.258794    75.404810    75.404810
# 3   2000-04-01  75.046897   59.320953   79.729758    75.046897    75.046897
# 4   2000-05-01  74.700531   71.575603   90.977033    74.700531    74.700531
# ..         ...        ...         ...         ...          ...          ...
# 308 2021-01-27  33.258117    2.709563   21.705392    33.258117    33.258117
# 309 2021-01-28  33.258407    3.979308   23.522154    33.258407    33.258407
# 310 2021-01-29  33.258697    5.550937   25.433191    33.258697    33.258697
# 311 2021-01-30  33.258987    8.083985   27.447667    33.258987    33.258987
# 312 2021-01-31  33.259277   10.164755   29.718559    33.259277    33.259280
#
#      additive_terms  additive_terms_lower  additive_terms_upper     yearly  \
# 0        -10.976443            -10.976443            -10.976443 -10.976443
# 1        -13.130641            -13.130641            -13.130641 -13.130641
# 2         -8.079099             -8.079099             -8.079099  -8.079099
# 3         -4.961968             -4.961968             -4.961968  -4.961968
# 4          6.675698              6.675698              6.675698   6.675698
# ..              ...                   ...                   ...        ...
# 308      -20.702684            -20.702684            -20.702684 -20.702684
# 309      -19.089095            -19.089095            -19.089095 -19.089095
# 310      -17.347377            -17.347377            -17.347377 -17.347377
# 311      -15.509743            -15.509743            -15.509743 -15.509743
# 312      -13.610763            -13.610763            -13.610763 -13.610763
#
#      yearly_lower  yearly_upper  multiplicative_terms  \
# 0      -10.976443    -10.976443                   0.0
# 1      -13.130641    -13.130641                   0.0
# 2       -8.079099     -8.079099                   0.0
# 3       -4.961968     -4.961968                   0.0
# 4        6.675698      6.675698                   0.0
# ..            ...           ...                   ...
# 308    -20.702684    -20.702684                   0.0
# 309    -19.089095    -19.089095                   0.0
# 310    -17.347377    -17.347377                   0.0
# 311    -15.509743    -15.509743                   0.0
# 312    -13.610763    -13.610763                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper       yhat
# 0                           0.0                         0.0  65.121101
# 1                           0.0                         0.0  62.608991
# 2                           0.0                         0.0  67.325711
# 3                           0.0                         0.0  70.084930
# 4                           0.0                         0.0  81.376228
# ..                          ...                         ...        ...
# 308                         0.0                         0.0  12.555433
# 309                         0.0                         0.0  14.169312
# 310                         0.0                         0.0  15.911320
# 311                         0.0                         0.0  17.749244
# 312                         0.0                         0.0  19.648513
#
# [313 rows x 16 columns]

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(24)
# Out:
#             ds       yhat  yhat_lower  yhat_upper
# 289 2021-01-08  17.074277    6.915546   26.831533
# 290 2021-01-09  15.930714    5.976740   25.888170
# 291 2021-01-10  14.741579    5.021238   24.409508
# 292 2021-01-11  13.534780    4.065712   22.673430
# 293 2021-01-12  12.340025    2.511919   23.047168
# 294 2021-01-13  11.188052    1.710513   21.146367
# 295 2021-01-14  10.109808    0.023960   19.685701
# 296 2021-01-15   9.135614   -0.535246   19.214268
# 297 2021-01-16   8.294329   -1.254436   17.566094
# 298 2021-01-17   7.612548   -2.010855   17.185030
# 299 2021-01-18   7.113843   -2.567421   16.713349
# 300 2021-01-19   6.818077   -3.039533   16.965678
# 301 2021-01-20   6.740811   -2.448679   16.461404
# 302 2021-01-21   6.892813   -2.503671   16.383975
# 303 2021-01-22   7.279695   -2.446426   17.424787
# 304 2021-01-23   7.901682   -2.185885   17.268891
# 305 2021-01-24   8.753516   -1.042099   19.162685
# 306 2021-01-25   9.824512    0.503171   19.046686
# 307 2021-01-26  11.098754    0.792963   21.410968
# 308 2021-01-27  12.555433    2.709563   21.705392
# 309 2021-01-28  14.169312    3.979308   23.522154
# 310 2021-01-29  15.911320    5.550937   25.433191
# 311 2021-01-30  17.749244    8.083985   27.447667
# 312 2021-01-31  19.648513   10.164755   29.718559

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)

# %% [markdown]
# # **6-Module Evaluation**

# %%
predictions = forecast.iloc[-len(test):]['yhat'].values
actual_values = test['y'].values

if len(predictions) > len(actual_values):
    predictions = predictions[:len(actual_values)]
else:
    actual_values = actual_values[:len(predictions)]

rmse_value = np.sqrt(mean_squared_error(actual_values, predictions))
mean_value = np.mean(actual_values)

print("Root Mean Squared Error between actual and predicted values:", rmse_value)
print("Mean Value of Test Dataset:", mean_value)
# Out:
# Root Mean Squared Error between actual and predicted values: 2873.2745051695474
# Mean Value of Test Dataset: 2566.284345047923

# %%
import pickle

pickle.dump(m, open('model1.pkl','wb'))

# %% [markdown]
# # **THANK YOU**
